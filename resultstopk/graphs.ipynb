# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data from the CSV
data = {
    "topk_patches_noise": [5, 8, 10, 15, 20, 25, 30, 40, 50, 60, 70, 85, 100, 120, 140, 160, 180, 200, 225, 256],
    "noise_ADM": [0.6921, 0.7104, 0.7240, 0.7239, 0.7370, 0.7420, 0.7529, 0.7608, 0.7614, 0.7708,
                  0.7798, 0.7774, 0.7888, 0.7976, 0.7995, 0.8037, 0.8079, 0.8088, 0.8151, 0.8139]
}

df = pd.DataFrame(data)

# Plot
plt.figure(figsize=(6, 4))
plt.plot(df["topk_patches_noise"], df["noise_ADM"], marker='o')
plt.xlabel("topk_patches_noise")
plt.ylabel("ADM AUROC (Noise)")
plt.title("ADM AUROC (Noise) vs topk_patches_noise")
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data from the CSV
data = {
    "topk_patches_blur": [5, 8, 10, 15, 20, 25, 30, 40, 50, 60, 70, 85, 100, 120, 140, 160, 180, 200, 225, 256],
    "blur_CollabDiff": [0.6408, 0.6679, 0.6820, 0.7075, 0.7256, 0.7398, 0.7499, 0.7671, 0.7785, 0.7872,
                        0.7945, 0.8022, 0.8085, 0.8142, 0.8182, 0.8215, 0.8236, 0.8257, 0.8274, 0.8296]
}

df = pd.DataFrame(data)

plt.figure(figsize=(6, 4))
plt.plot(df["topk_patches_blur"], df["blur_CollabDiff"], marker='o')
plt.xlabel("topk_patches_blur")
plt.ylabel("CollabDiff AUROC (Blur)")
plt.title("CollabDiff AUROC (Blur) vs topk_patches_blur")
plt.grid(True)
plt.tight_layout()
plt.show()
